# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-mehul/Personal-projects/blob/main/exponential_dist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exponential distribution 
import matplotlib.pyplot as plt
import numpy as np 
from math import e

# %%
#data for distribution 
test_data = [1,5]  
theta = sum(test_data)/len(test_data)
#x = theta 
#print(x)


#making the concept clear we need to replace the value everytime of tthe list as well as constantly update it therefor we create some sort of a distribution 
#or get the values between the numbers 
#i = 0
#x = float()
#while(i < 100 and theta<5):
#  test_data.append(theta)
#  test_data.sort()
#  new_length = len(test_data)
#  theta = sum(test_data)/new_length
#  i = i+1
#  print(theta)
#  print(test_data)





i = 0
x = int()
while(i<100 and theta<15):
  test_data.append(theta)
  theta = x
  x = 0
  test_data.sort()
  print(test_data)
  i = i+1
  theta = (test_data[i]+test_data[i+1])/2
# Out:
# [1, 3.0, 5]
# [1, 3.0, 4.0, 5]
# [1, 3.0, 4.0, 4.5, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 4.99609375, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 4.99609375, 4.998046875, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 4.99609375, 4.998046875, 4.9990234375, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 4.99609375, 4.998046875, 4.9990234375, 4.99951171875, 5]
# [1, 3.0, 4.0, 4.5, 4.75, 4.875, 4.9375, 4.96875, 4.984375, 4.9921875, 4.99609375, 4.998046875, 4.9990234375, 4.99951171875, 4.999755859375, 5]
# ...

# %%
test_data_refined = list(set(test_data))

# %%
test_data_refined.sort()

# %%
theta = sum(test_data_refined)/len(test_data_refined)
print(theta)
# Out:
# 4.851851851851852

# %%
non_power=theta*e
power = np.multiply(theta,test_data_refined)
exp = non_power**power

# %%
plt.plot(exp)
